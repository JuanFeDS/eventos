# %% [markdown]
# # **Exploración inicial — streamly_churn.csv**

# %% [markdown]
# ### **Librerías**

# %%
import pandas as pd 
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### **Datos**

# %%
df = pd.read_csv('data.csv')
